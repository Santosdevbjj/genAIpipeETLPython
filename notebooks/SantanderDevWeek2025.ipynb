# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosdevbjj/genAIpipeETLPython/blob/main/notebooks/SantanderDevWeek2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Santander Dev Week 2025 - ETL com IA Generativa\n",
    "Demonstração do pipeline ETL (Extract, Transform, Load) usando o repositório local."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "!git clone https://github.com/Santosdevbjj/genAIpipeETLPython.git\n",
    "import os\n",
    "os.chdir('genAIpipeETLPython/etl')\n",
    "!python -m venv .venv && source .venv/bin/activate && pip install -r requirements.txt\n",
    "from etl.clients.ai_provider import MockAIProvider\n",
    "from etl.pipeline import run_pipeline\n",
    "run_pipeline(input_path='data/clientes.xlsx', api_base=os.getenv('API_BASE', 'http://localhost:8080/api'), jwt_token=os.getenv('JWT_TOKEN',''), ai_provider=MockAIProvider(), channel='app', ids=[1,2,3])"
   ],
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
